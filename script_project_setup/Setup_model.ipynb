# %% [markdown]
# # Setup model

# %% [raw]
# 1) Average_watershed_values.py
# 2) Load_Discharge_RSE_file.py
# 3) CreateDatabaseSqlite.py
# 4) Upload_TimeSeries.py
# 5) GraphFromDB.py

# %% [markdown]
# ## Input_Setup.ini

# %% [raw]
# [globalOptions]
#
# # Set the input output dir
# MainDirInput = ../InputData
#
# MainDirOutput = ../TimeSeries
#
# ProjectPath = ../Project
#
# [input_data]
#
# # catchment polygon
# InputPolygonFile = outlet_catchment.gpkg
#
# # Files NetCDF
# surface_runoff = RF_1951_2022.nc
# groundwater_recharge = GR_1951_2022.nc
#
# # DischargeFile_RSE
# Discharge_file_RSE = Historical_data_Tolignano.csv
#
# [output]
#
# surface_runoff_csv = runoff.csv
# groundwater_recharge_csv = recharge.csv
# historical_river_flows_csv = Q_historical.csv
#
# [Input_par]
# # ProjectName
# ProjectName = Tronto
#
# Description= Tronto at Tolignano
# AreaKmq = 901.0
# phi = 1.0
# k = 2.0
# n = 3.00
# phisup = 1.0
# ksup = 1.0
#
# # minmax default
# # relationship between surface and groundwater basin area
# phi_min_max = 0.0, 8.0
# # depletion constant of the basic runoff Nash model
# k_min_max = 1.0, 3.0
# # Number of linear reservoirs in series of the baseflow Nash model
# n_min_max = 1.0, 3.0
# # increase in superficial basin area
# phi_sup_min_max = 0.9, 1.1
# # depletion constant of the linear reservoir model of surface runoff
# k_sup_min_max = 1.0, 2.0

# %% [markdown]
# # let's show the file

# %%
! type Input_Setup.ini
# Out:
# [globalOptions]
#
# # Set the input output dir
# MainDirInput = ../InputData
#
# MainDirOutput = ../TimeSeries
#
# ProjectPath = ../Project
#
# [input_data]
#
# # catchment polygon
# InputPolygonFile = outlet_catchment.gpkg
#
# # Files NetCDF
# surface_runoff = RF_1951_2022.nc
# groundwater_recharge = GR_1951_2022.nc
#
# # DischargeFile_RSE
# Discharge_file_RSE = Historical_data_Tolignano.csv
#
# [output]
#
# surface_runoff_csv = runoff.csv
# groundwater_recharge_csv = recharge.csv
# historical_river_flows_csv = Q_historical.csv
#
# [Input_par]
# # ProjectName
# ProjectName = Tronto
#
# Description= Tronto at Tolignano
# AreaKmq = 901.0
# phi = 1.0
# k = 2.0
# n = 3.00
# phisup = 1.0
# ksup = 1.0
#
# # minmax default
# # relationship between surface and groundwater basin area
# phi_min_max = 0.0, 8.0
# # depletion constant of the basic runoff Nash model
# k_min_max = 1.0, 3.0
# # Number of linear reservoirs in series of the baseflow Nash model
# n_min_max = 1.0, 3.0
# ...

# %% [markdown]
# # run Average_watershed_values.py

# %%
# %run Average_watershed_values.py
# Out:
# Saved file: C:\DiscoD\GlobalData2024\Elab_Tronto\TimeSeries\runoff.csv
# Saved file: C:\DiscoD\GlobalData2024\Elab_Tronto\TimeSeries\recharge.csv
# OK

# %% [markdown]
# ## run Load_Discharge_RSE_file.py

# %%
# %run Load_Discharge_RSE_file.py
# Out:
# NoData for year: 1943
# NoData for year: 1944
# NoData for year: 1945
# NoData for year: 1964
# NoData for year: 1965
# NoData for year: 1966
# NoData for year: 1967
# NoData for year: 1968
# NoData for year: 1969
# Saved file: C:\DiscoD\GlobalData2024\Elab_Tronto\TimeSeries\Q_historical.csv
# OK

# %% [markdown]
# ## run CreateDatabaseSqlite.py

# %%
# %run CreateDatabaseSqlite.py
# Out:
# OK

# %% [markdown]
# ## run Upload_TimeSeries.py

# %%
# %run Upload_TimeSeries.py
# Out:
# Upload Runoff
# Upload Recharge
# Upload QtotObs
# OK

# %% [markdown]
# ## run GraphFromDB.py

# %%
# %run GraphFromDB.py
# Out:
# OK
